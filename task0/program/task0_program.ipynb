# %%
import os
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e26966f9ef6d> in <module>
#       1 import os
# ----> 2 os.chdir("~/2020_eco_geo/task0/program")
#       3 import matplotlib.pyplot as plt
#       4 import japanize_matplotlib
#       5 import pandas as pd
#
# FileNotFoundError: [WinError 3] 指定されたパスが見つかりません。: '~/2020_eco_geo/task0/program'

# %%
df=pd.read_csv("../data/longterm_pop.csv")

fig=plt.figure(figsize=(6,3),dpi=300)
fig.suptitle("2000年から2015年までの日本の人口推移")
ax=fig.add_subplot(111)
ax.plot(df["pop"])
label=list(" ")
label.extend(df["year"][list(range(0,len(df["year"]),2))])
ax.set_xticklabels(label)
fig.savefig("../data/pop_plot.png")
